# %%
import pandas as pd

# %%
#http://localhost:8888/view/sample.html
dfs = pd.read_html('sample.html')
dfs[0]
# Out:
#     HS6                        Importers  Imported value in 2019-M08  \
# 0   NaN         United States of America                       90151
# 1   NaN                            China                       60092
# 2   NaN                     South Africa                       43920
# 3   NaN                           France                       39801
# 4   NaN               Korea, Republic of                       10946
# 5   NaN                           Turkey                        4772
# 6   NaN                            Japan                       49904
# 7   NaN                        Australia                       20179
# 8   NaN                           Brazil                       26211
# 9   NaN                            Chile                        5682
# 10  NaN                      Switzerland                        5497
# 11  NaN                          Bahrain                        4155
# 12  NaN                           Norway                        2905
# ...

# %%
df = pd.read_json('json/countries.json')
df
# Out:
#      code                       name  description  parentCode  \
# 0       4                Afghanistan          NaN          13
# 1       8                    Albania          NaN           6
# 2      12                    Algeria          NaN          11
# 3      16             American Samoa          NaN          12
# 4      20                    Andorra          NaN           4
# ..    ...                        ...          ...         ...
# 221   876  Wallis and Futuna Islands          NaN          12
# 222   732             Western Sahara          NaN          11
# 223   887                      Yemen          NaN           9
# 224   894                     Zambia          NaN          14
# 225   716                   Zimbabwe          NaN          14
#
#                                                 parent  color subRegions  \
# 0    {'code': '13', 'name': 'South Asia', 'descript...    NaN         []
# ...

# %%
def
