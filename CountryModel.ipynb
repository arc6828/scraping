# %%
import pandas as pd

# %%
df = pd.read_json('json/countries.json')
df
# Out:
#      code                       name  description  parentCode  \
# 0       4                Afghanistan          NaN          13
# 1       8                    Albania          NaN           6
# 2      12                    Algeria          NaN          11
# 3      16             American Samoa          NaN          12
# 4      20                    Andorra          NaN           4
# ..    ...                        ...          ...         ...
# 221   876  Wallis and Futuna Islands          NaN          12
# 222   732             Western Sahara          NaN          11
# 223   887                      Yemen          NaN           9
# 224   894                     Zambia          NaN          14
# 225   716                   Zimbabwe          NaN          14
#
#                                                 parent  color subRegions  \
# 0    {'code': '13', 'name': 'South Asia', 'descript...    NaN         []
# ...

# %%
with pd.ExcelWriter('countries.xlsx') as writer:
    df.to_excel(writer)

# %%
df = pd.read_excel('countries.xlsx', sheet_name="final")  
df
# Out:
#      code                       name           iso_name iso_code
# 0       4                Afghanistan        Afghanistan       AF
# 1       8                    Albania            Albania       AL
# 2      12                    Algeria            Algeria       DZ
# 3      16             American Samoa     American Samoa       AS
# 4      20                    Andorra            Andorra       AD
# ..    ...                        ...                ...      ...
# 217   876  Wallis and Futuna Islands  Wallis and Futuna       WF
# 218   732             Western Sahara     Western Sahara       EH
# 219   887                      Yemen              Yemen       YE
# 220   894                     Zambia             Zambia       ZM
# 221   716                   Zimbabwe           Zimbabwe       ZW
#
# [222 rows x 4 columns]

# %%
df.to_json('json/final-countries.json', orient="records")
